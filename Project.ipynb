# %% [markdown]
# <a href="https://colab.research.google.com/github/EstebanJM/V.Data/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROJECT**

# %% [markdown]
# # 1. Variable

# %% [markdown]
# ## 1.1. Name and description.
#
# * **Current:** it's the current number of players on steam per video game
#
# * **24 hours peak:** maximum number players on steam in 24 hours per video game
#
# * **All-time Peak:** This variable refers, to the maximum number of players on steam per video game.

# %% [markdown]
# ## 1.2. Period or dates. Frequency. Individuals.
#
# * **Period or dates. Frequency:** It will be a cross section for the date March 11, 2023 - at 7:00 pm. To capture more players in the "current" variable.
# * **Individuals:** Top 10 video games for each variable

# %% [markdown]
#  ## 1.3. Sources (with links).
#  Steam platform database
#  [Steamdb](https://steamdb.info/charts/)

# %% [markdown]
# # 2. Goal of the DV

# %% [markdown]
# ## 2.1.Story.
#
# The video game industry is constantly growing, and there are more and more players, so I want to share the top 10 most played video games on steam, to provide gaming options to gamers.

# %% [markdown]
# ## 2.2. Audience.
# Gamers and people interested in video games

# %% [markdown]
# ## 2.3. Justify the DV type.
# * **Bar chart and Treemap:** allow to compare in an organized and hierarchical way each video game by number of players.

# %% [markdown]
# # 3. Example:

# %% [markdown]
# ## 3.1 Example 1:
# [Example 1](https://i.redd.it/wxvhlyy075la1.png)
# ![Ejemplo 1.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.2 Example 2:
# [Example 2](https://i.redd.it/x29oc76543i91.png)
# ![Ejemplo 2.png](data:image/png;base64,...)
